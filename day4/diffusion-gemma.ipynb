# %%
from transformers import DiffusionGemmaForBlockDiffusion, AutoProcessor

MODEL_ID = "google/diffusiongemma-26B-A4B-it"

# Load model
processor = AutoProcessor.from_pretrained(MODEL_ID)
model = DiffusionGemmaForBlockDiffusion.from_pretrained(
    MODEL_ID,
    dtype="auto",
    device_map="auto",
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       3 MODEL_ID = "google/diffusiongemma-26B-A4B-it"
#       4
#       5 # Load model
#       6 processor = AutoProcessor.from_pretrained(MODEL_ID)
# ----> 7 model = DiffusionGemmaForBlockDiffusion.from_pretrained(
#       8     MODEL_ID,
#       9     dtype="auto",
#      10     device_map="auto",
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/transformers/modeling_utils.py:4222, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4217     logger.warning_once(
#    4218         "A kernel_config was provided but use_kernels is False; setting use_kernels=True automatically. To suppress this warning, explicitly set use_kernels to True."
#    4219     )
#    4220     use_kernels = True
# -> 4222 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4223     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4224     variant=variant,
#    4225     gguf_file=gguf_file,
#    4226     use_safetensors=use_safetensors,
#    4227     download_kwargs=download_kwargs_with_commit,
#    4228     user_agent=user_agent,
#    4229     is_remote_code=cls.is_remote_code(),
#    4230     transformers_explicit_filename=getattr(config, "transformers_weights", None),
#    4231     tqdm_class=tqdm_class,
#    4232 )
#    4234 is_quantized = hf_quantizer is not None
#    4236 # Find the correct dtype based on current state
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/transformers/modeling_utils.py:797, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, variant, gguf_file, use_safetensors, user_agent, is_remote_code, transformers_explicit_filename, download_kwargs, tqdm_class)
#     795 sharded_metadata = None
#     796 if is_sharded:
# --> 797     checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#     798         pretrained_model_name_or_path,
#     799         resolved_archive_file,
#     800         cache_dir=cache_dir,
#     801         force_download=force_download,
#     802         proxies=proxies,
#     803         local_files_only=local_files_only,
#     804         token=token,
#     805         user_agent=user_agent,
#     806         revision=revision,
#     807         subfolder=subfolder,
#     808         _commit_hash=commit_hash,
#     809         tqdm_class=tqdm_class,
#     810     )
#     811 else:
#     812     checkpoint_files = [resolved_archive_file] if pretrained_model_name_or_path is not None else None
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/transformers/utils/hub.py:894, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, subfolder, _commit_hash, tqdm_class, **deprecated_kwargs)
#     890     return shard_filenames, sharded_metadata
#     892 # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#     893 # or download the files
# --> 894 cached_filenames = cached_files(
#     895     pretrained_model_name_or_path,
#     896     shard_filenames,
#     897     cache_dir=cache_dir,
#     898     force_download=force_download,
#     899     proxies=proxies,
#     900     local_files_only=local_files_only,
#     901     token=token,
#     902     user_agent=user_agent,
#     903     revision=revision,
#     904     subfolder=subfolder,
#     905     _commit_hash=_commit_hash,
#     906     tqdm_class=tqdm_class,
#     907 )
#     909 return cached_filenames, sharded_metadata
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/transformers/utils/hub.py:452, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#    (...)    449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
# --> 452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#     455             repo_type=repo_type,
#     456             revision=revision,
#     457             cache_dir=cache_dir,
#     458             user_agent=user_agent,
#     459             force_download=force_download,
#     460             proxies=proxies,
#     461             token=token,
#     462             local_files_only=local_files_only,
#     463             tqdm_class=tqdm_class,
#     464         )
#     466 except Exception as e:
#     467     # We cannot recover from them
#     468     if isinstance(e, RepositoryNotFoundError) and not isinstance(e, GatedRepoError):
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/huggingface_hub/_snapshot_download.py:455, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, dry_run)
#     433 def _inner_hf_hub_download(repo_file: str) -> None:
#     434     results.append(
#     435         hf_hub_download(  # type: ignore
#     436             repo_id,
#    (...)    452         )
#     453     )
# --> 455 thread_map(
#     456     _inner_hf_hub_download,
#     457     filtered_repo_files,
#     458     desc=tqdm_desc,
#     459     max_workers=max_workers,
#     460     tqdm_class=tqdm_class,
#     461 )
#     463 bytes_progress.set_description("Download complete")
#     465 if dry_run:
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)     66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     yield from it
#     251 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     252 except:  # NOQA
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/.pyenv/versions/3.12.13/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
